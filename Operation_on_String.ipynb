# %%
a=[1,2,3,4,5]
popped_element=a.pop(4)
a.insert(0,popped_element)
print(a)
# Out:
# [5, 1, 2, 3, 4]

# %%
a=[4,2,3,1]
for i in range(len(a)-1):
  for j in range(1,len(a)-1):
    if a[i] > a[j]:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/1848191570.py in <cell line: 0>()
#       1 a=[4,2,3,1]
# ----> 2 for i in range((a)-1):
#       3   if a[i] > a[i+1]:
#       4     a[i],a[i+1]=a[i+1],a[i]
#       5   print(a)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
key=int(input())
a=[3,4,6,7,2]
for i in a:
  i==key
if i==a[i]:
    print("found")
else :
  print("not found")
# Out:
# 4
# not found

# %%
string="sandip"
string[0:3]
# Out:
# 'san'

# %%
string="sandip"
string[::3]
# Out:
# 'sd'

# %%
a=10
b=5
print("a:",a,"b:",b)
print("a={} b={} a+b{}".format(a,b,a+b))
print(f"a={a} b={b} a+b{a+b}")
# Out:
# a: 10 b: 5
# a=10 b=5 a+b15
# a=10 b=5 a+b15

# %%
a=10
c=10
print(id(a),id(c))
b=10
print(id(c))
# Out:
# 11645640 11645640
# 11645640

# %%
a=10
print(id(a))
a=20
print(id(a))
# Out:
# 11645640
# 11645960

# %%
lst[10]
print(id(lst))
lst[0]=20
print(id(lst))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/768206836.py in <cell line: 0>()
# ----> 1 lst[10]
#       2 print(id(lst))
#       3 lst[0]=20
#       4 print(id(lst))
#
# TypeError: 'int' object is not subscriptable

# %%
str=input()
rev_string=str[::-1]
if str==rev_string:
  print("string is palindrome")
else:
  print("string is not palindrome")
# Out:
# nayan
# string is palindrome

# %%
ord("s")
# Out:
# 115

# %%
string=input()
ascii=0
new_str=""
new_ascii=0
for i in string:
  ascii=ord(i)
  new_ascii=ascii-32
  new_chr=chr(new_ascii)
  new_str+=new_chr
print(new_str)
# Out:
# sandip
# SANDIP

# %%
string=input()
new_str=""
for i in string:
  new_str+=chr(ord(i)-32)
print(new_str)
# Out:
# sam
# SAM

# %%
string=input()
new_str=""
for i in string:
  new-str+=chr(ord(i)+32)
# Out:
#   File "/tmp/ipykernel_15466/252861217.py", line 4
#     new-str+=chr(ord(i)+32)
#     ^
# SyntaxError: 'expression' is an illegal expression for augmented assignment
