# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a|b
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a&b
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a-b
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a^b
# Out:
# {1, 4, 5, 7}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.intersection(b)
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 7}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.difference(b)
# Out:
# {1, 4}

# %%
(a|b)-(a&b)
# Out:
# {1, 4, 5, 7}

# %%
dct={1:"abc",2:"pqr"}
print(dct)
# Out:
# {1: 'abc', 2: 'pqr'}

# %%
for i in dct.keys():
  print(i)
# Out:
# 1
# 2

# %%
dct={1:"swarali",2:"neha",3:"pallavi",4:"janhavi",5:"shreya"}
for i,j  in dct.items():
  print(f"Roll No {i} is {j}")
# Out:
# Roll No 1 is swarali
# Roll No 2 is neha
# Roll No 3 is pallavi
# Roll No 4 is janhavi
# Roll No 5 is shreya

# %%
dct[3]="mno"
print(dct)
# Out:
# {1: 'swarali', 2: 'neha', 3: 'mno', 4: 'janhavi', 5: 'shreya'}

# %%
dct[6]="abc"
print(dct)
# Out:
# {1: 'swarali', 2: 'neha', 3: 'mno', 4: 'janhavi', 5: 'shreya', 6: 'abc'}

# %%
dct.get(2)
# Out:
# 'neha'

# %%
dct.get(2,"not found")
# Out:
# 'neha'

# %%
sample={"days":["mon","tue","wed","thu"],
         "planets":["sun","saturn","earth"]}
for key,values in sample.items():
    print(values)
# Out:
# ['mon', 'tue', 'wed', 'thu']
# ['sun', 'saturn', 'earth']

# %%
sample={"percentage":("99.8","79.6","39","67"),
         {"Name","id","collegename"}:"1"}
for key,values in sample.items():
    print(key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_580/4140421181.py in <cell line: 0>()
# ----> 1 sample={"percentage":("99.8","79.6","39","67"),
#       2          {"Name","id","collegename"}:"1"}
#       3 for key,values in sample.items():
#       4     print(key)
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# pattern priting

# %%
n=3
for i in range(n,0,-1):
  for j in range(i,4):
    print("*",end="")
  print()
# Out:
# *
# **
# ***

# %%
n=int(input())
for row in range(n):
  for col in range(n):
    ele=max(row+1,col+1,n-row,n-col)
    print(ele,end=" ")
  print()
# Out:
# 5
# 5 5 5 5 5
# 5 4 4 4 5
# 5 4 3 4 5
# 5 4 4 4 5
# 5 5 5 5 5
