# %%
import numpy as np
a=np.arange(1,10)
print(a)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
a=np.arange(1,10).reshape(3,3)
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
a.shape
# Out:
# (3, 3)

# %%
a.t
